# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("APPLE.csv")

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df["DATE"] = pd.to_datetime(df["Date"],utc=True)

# %%
df = df.sort_values("DATE")

# %%
plt.figure(figsize=(16, 8))

plt.plot(df.index, df["Open"], label="open")
plt.plot(df.index, df["High"], label="high")
plt.plot(df.index, df["Low"], label="low")
plt.plot(df.index, df["Close"], label="close")

plt.title("Apple Stock Chart")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 8))

plt.plot(df['DATE'], df["Volume"], label="volume")

plt.title("Date Volume Analysis")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.legend()
plt.show()

# %%
df["MA20"] = df["Close"].rolling(window=20).mean()

df["MA50"] = df["Close"].rolling(window=50).mean()

# %%
plt.figure(figsize=(16, 8))

plt.plot(df['DATE'], df['MA20'])

plt.title("DAY 20 Stock Detail")
plt.xlabel("Date")
plt.ylabel("price")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_2006/4288898075.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(16, 8))

plt.plot(df['DATE'], df['MA50'])

plt.title("DAY 20 Stock Detail")
plt.xlabel("Date")
plt.ylabel("price")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_2006/2144280913.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df['Daily_Return'] = df['Close'].pct_change()

# %%
plt.figure(figsize=(16, 8))
plt.histplot(
    df['Daily_Return'].dropna()
    bin(50)
    KDE=True
    plt.title("Histogram Plot")
    plt.xlabel("Return")
    plt.ylabel("price")
)
# Out:
#   File "/tmp/ipykernel_2006/415123040.py", line 3
#     df['Daily_Return'].dropna()
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
